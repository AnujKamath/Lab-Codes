# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# 1. Follow along with these steps:
# a) Create a figure object called fig using plt.figure()
# b) Use add_axes to add an axis to the figure canvas at [0,0,1,1]. Call this new axis ax.
# c) Plot (x,y) on that axes and set the labels and titles to match the plot below:

fig = plt.figure() 
ax = fig.add_axes([0,0,1,1])
# x1=[0,20,40,60,80,100]
y1=[0,50,100,150,200]
ax.set_title("title")
ax.set_xlim(0,100)  # Set x-axis limits
ax.set_ylim(0,200)  # Set y-axis limits
plt.yticks(y1) 

plt.plot([0,100],[0,200])
# fig.show()

# %%
# 2. Create a figure object and put two axes on it, ax1 and ax2. Located at [0,0,1,1] and [0.2,0.5,.2,.2]
# respectively. Now plot (x,y) on both axes. And call your figure object to show it.

fig=plt.figure()
ax1=fig.add_axes([0,0,1,1])
ax2=fig.add_axes([0.2,0.5,.2,.2])
ax1.plot([0,100],[0,200])
ax2.plot([0,100],[0,200])

fig.show()
# Out:
# /tmp/ipykernel_8458/4048147452.py:10: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
# 3. Use the company sales dataset csv file, read Total profit of all months and show it using a line plot
# Total profit data provided for each month. Generated line plot must include the following properties: –
# a. X label name = Month Number
# b. Y label name = Total profit

df=pd.read_csv('company_sales_data.csv')
# df['total_profit'].plot()
plt.plot(df['month_number'],df['total_profit'])
plt.xlabel('Month Number')
plt.ylabel('Total Profit')
plt.xticks(df['month_number']) 
plt.show()

# %%
# 4. Use the company sales dataset csv file, get total profit of all months and show line plot with the following
# Style properties. Generated line plot must include following Style properties: –
# a. Line Style dotted and Line-color should be red
# b. Show legend at the lower right location.
# c. X label name = Month Number
# d. Y label name = Sold units number
# e. Add a circle marker.
# f. Line marker color as read
# g. Line width should be 3

df=pd.read_csv('company_sales_data.csv')
plt.plot(df['month_number'],df['total_units'],linestyle = 'dotted',color='r',label='line',marker='o',mfc='r',linewidth='3')
plt.xlabel('Month Number')
plt.ylabel('Sold units number')
plt.xticks(df['month_number']) 
plt.legend(loc="lower right")
plt.show()

# %%
# add1. Use the company sales dataset csv file, read all product sales data and show it using a multiline plot.
# Display the number of units sold per month or each product using multiline plots. (i.e., Separate Plotline
# for each product ).

for column in df.columns[1:7]:
    plt.plot(df['month_number'], df[column], label=column)
plt.legend()

# %%
# Use the company sales dataset csv file, calculate total sale data for last year for each product and show it
# using a Pie chart.
# Note: In Pie chart display Number of units sold per year for each product in percentage.

df1=df.drop(columns=['month_number','total_units','total_profit'])
column_sums = df1.select_dtypes(include='number').sum()
sums_list = column_sums.tolist()
column_labels = column_sums.index

plt.pie(sums_list, labels=column_labels, autopct='%1.1f%%', startangle=140)
plt.show()

# %%
plt.pie(df.columns[1:7].sum(),labels=)
